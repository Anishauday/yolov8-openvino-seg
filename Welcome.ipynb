# %% [markdown]
# ### Style Transfer demo (Option A: cv2 popup)
#
# 1. Run the cell below to launch the Gradio app
# 2. Choose style and device (CPU/GPU/NPU) from the dropdowns
# 3. Check **Use webcam?** for camera, or uncheck for video file
# 4. Click **Start** – styled video opens in a **cv2 popup** (stays on top of browser)
# 5. Click **Clear inputs and stop** or press **Q** in the video window to stop
#
# **Note:** Video displays in a native OpenCV window for smooth live playback; Gradio is for controls only.

# %%
import importlib
import style_utils
importlib.reload(style_utils)  # Force reload so you always get the latest code
import warnings
warnings.filterwarnings('ignore')

style_demo = style_utils.build_gr_interface()
style_demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://23db3c1ddf991c4df5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://23db3c1ddf991c4df5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip show gradio

# %%
# !python download_install.py
