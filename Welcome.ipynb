# %% [markdown]
# ### Style Transfer demo (Option A: cv2 popup)
#
# **Launch next time:** Activate venv, then start Jupyter:
# ```powershell
# cd c:\Users\anish\Cursor\Openvino\openvino_build_deploy\trainings\Style_Transfer
# .\env_ov\Scripts\Activate.ps1
# jupyter lab
# ```
# Open this notebook, select **OpenVINO** kernel, run the launch cell.
#
# **In the app:**
# 1. Choose style and device (CPU/GPU/NPU) from the dropdowns
# 2. Check **Use webcam?** for camera, or uncheck for video file
# 3. Click **Start** – styled video opens in a **cv2 popup** (stays on top of browser)
# 4. Click **Clear inputs and stop** or press **Q** in the video window to stop
#
# **Note:** Video displays in a native OpenCV window for smooth live playback; Gradio is for controls only.

# %%
import importlib
import style_utils
importlib.reload(style_utils)  # Force reload so you always get the latest code
import warnings
warnings.filterwarnings('ignore')

style_demo = style_utils.build_gr_interface()
style_demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://fd6eff0570c6fc1a49.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fd6eff0570c6fc1a49.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip show gradio

# %%
# !python download_install.py
